# %%
import pandas as pd

data = pd.read_csv('F:\\CodingEnvironment\\tog\\ToG\\questions_filtered.csv')
# Out:
#     question_id                                         file_name  \
# 0             1      Thông_tin_chung_về_công_ty_FPT_Smart_Cloud_2
# 1             2      Thông_tin_chung_về_công_ty_FPT_Smart_Cloud_2
# 2             3      Thông_tin_chung_về_công_ty_FPT_Smart_Cloud_2
# 3             4      Thông_tin_chung_về_công_ty_FPT_Smart_Cloud_2
# 4             5      Thông_tin_chung_về_công_ty_FPT_Smart_Cloud_2
# 5             6      Thông_tin_chung_về_công_ty_FPT_Smart_Cloud_2
# 6             7      Thông_tin_chung_về_công_ty_FPT_Smart_Cloud_2
# 7            10                                 Giới_thiệu_FPT.AI
# 8            11                                 Giới_thiệu_FPT.AI
# 9            12                                 Giới_thiệu_FPT.AI
# 10           13                                 Giới_thiệu_FPT.AI
# 11           14                                 Giới_thiệu_FPT.AI
# 12           15                                 Giới_thiệu_FPT.AI
# ...

# %%
data['question']
# Out:
# 0     Ai là chủ tịch hội đồng quản trị của FPT Smart...
# 1           Tổng giám đốc công ty FPT Smart Cloud là ai
# 2            Ông Lý Việt Thắng làm gì ở FPT Smart Cloud
# 3     Cho tôi biết ai là phó giám đốc khối Công nghệ...
# 4     Khối vận hành của FPT Smart Cloud có những phò...
# 5      Đội ngũ lãnh đạo của FPT Smart Cloud có những ai
# 6               Tầm nhìn chiến lược của FPT Smart Cloud
# 7                                          FPT AI là gì
# 8                        Kể tên các ứng dụng của FPT AI
# 9                     FPT AI Chat khác gì FPT AI Engage
# 10                            Mục tiêu của FPT AI là gì
# 11    Sản phẩm nền tảng nhận diện và trích xuất thôn...
# 12                           FPT AI eKYC có khả năng gì
# 13                Giải pháp FPT.AI được kì vọng thế nào
# 14      Liệt kê các công ty thành viên của tập đoàn FPT
# 15    Tập đoàn FPT có thuộc top 100 doanh nghiệp lớn...
# 16          Kể tên một vài thành tựu mà FPT đã đạt được
# ...
